# %%
import pandas as pd

# %%
Movies = pd.read_csv(r'D:\New folder\DS\files\25th\25th\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv')

# %%
Movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
Movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
len(Movies)
# Out:
# 559

# %%
Movies.shape
# Out:
# (559, 6)

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
Movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
Movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
Movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
Movies.Film = Movies.Film.astype('category')

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
Movies.Genre = Movies.Genre.astype('category')
Movies.Year = Movies.Year.astype('category')

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %%
vis1 = sns.jointplot(data=Movies,x='CriticRating',y='AudienceRating')

# %%
vis2 = sns.jointplot(data=Movies,x='CriticRating',y='AudienceRating',kind='hex')

# %%
vis3 = sns.jointplot(data=Movies,x='CriticRating',y='AudienceRating',kind='hist')

# %%
vis4 = sns.jointplot(data=Movies,x='CriticRating',y='AudienceRating',kind='kde')

# %%
m1 = sns.distplot(Movies.AudienceRating)

# %%
sns.set_style('darkgrid')

# %%
m1 = sns.distplot(Movies.AudienceRating,bins=15)

# %%
n1 = plt.hist(Movies.AudienceRating, bins=15)

# %%
plt.hist(Movies.BudgetMillions)
plt.show()

# %%
vis5 = sns.lmplot(data=Movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=False)

# %%
vis6 = sns.lmplot(data=Movies, x='CriticRating', y='AudienceRating',
                 fit_reg=False, hue = 'Genre')

# %%
vis7 = sns.lmplot(data=Movies, x='CriticRating', y='AudienceRating',
                 fit_reg=False, hue = 'Genre', aspect=1)

# %%
vis7 = sns.lmplot(data=Movies, x='CriticRating', y='AudienceRating',
                 fit_reg=False, hue = 'Genre', aspect=1,height=10)

# %%
k1 = sns.kdeplot(Movies.CriticRating)

# %%
k1 = sns.kdeplot(data=Movies,x='CriticRating',y='AudienceRating')

# %%
k2 = sns.kdeplot(data=Movies,x='CriticRating',y='AudienceRating',shade = True,shade_lowest=False,cmap='Reds')

# %%
ax = plt.subplots(1,2, figsize =(12,6))

# %%
f,axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(data=Movies ,x='BudgetMillions',y='AudienceRating',ax=axes[0])
k2 = sns.kdeplot(data=Movies ,x='BudgetMillions',y='AudienceRating',ax=axes[1])

# %%
a=sns.boxplot(data=Movies,x='Genre',y='CriticRating')

# %%
b=sns.violinplot(data=Movies,x='Genre',y='CriticRating')

# %%
c=sns.boxplot(data=Movies[Movies.Genre=='Drama'],x='Year',y='CriticRating')

# %%
d=sns.FacetGrid(Movies,row='Genre',col='Year',hue='Genre')

# %%
plt.scatter(Movies.CriticRating,Movies.AudienceRating)

# %%
d=sns.FacetGrid(Movies,row='Genre',col='Year',hue='Genre')
d=d.map(plt.scatter,'CriticRating','AudienceRating')

# %%
d =sns.FacetGrid (Movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
d = d.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws )

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1= sns.kdeplot(data=Movies,x='BudgetMillions',y='AudienceRating',ax=axes[0,0])
k2 = sns.kdeplot(data=Movies,x='BudgetMillions',y='CriticRating',ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

sns.violinplot(data=Movies[Movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

sns.kdeplot(data=Movies,x='CriticRating',y='AudienceRating',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

sns.kdeplot(data=Movies,x='CriticRating',y='AudienceRating',cmap='Reds',ax = axes[1,1])

plt.show()
